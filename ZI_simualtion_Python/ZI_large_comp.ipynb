# %%
import numpy as np
import pandas as pd
from scipy.stats import pearsonr
from tqdm.notebook import trange
np.random.seed(1234)

import nbimporter

from class_function import *

# %% [markdown]
# # Settings

# %%
###########
# Large 1 #
###########

# Create vector holding all the values and costs
Values_large1 = [[148, 138, 118], [147, 137, 117], [140, 120, 100], [149, 139, 119], [146, 136, 116],
                 [150, 130, 110], [149, 129, 109], [148, 128, 108], [147, 127, 107], [146, 126, 106], 
                 [144, 124, 104], [145, 125, 105], [141, 131, 111], [143, 123, 103], [142, 122, 102], 
                 [141, 121, 101], [145, 135, 115], [142, 132, 112], [143, 133, 113], [144, 134, 114]]
Costs_large1 = [[62, 82, 102], [63, 83, 103], [60, 80, 100], [61, 81, 101], [64, 84, 104], 
                [50, 70, 90], [51, 71, 91], [52, 72, 92], [53, 73, 93], [54, 74, 94], 
                [56, 76, 96], [55, 75, 95], [69, 89, 109], [57, 77, 97], [58, 78, 98], 
                [59, 79, 99], [65, 85, 105], [68, 88, 108], [67, 87, 107], [66, 86, 106]]

setting_large1 = {
    "numberBuyers": 20,
    "numberSellers": 20,
    "Quantity": 3,
    "bound": 300,
    "Values": Values_large1,
    "Costs": Costs_large1
}

###########
# Large 2 #
###########

# Create vector holding all the values and costs
Values_large2 = [[150, 141, 132, 129, 120, 111], [147, 138, 129, 126, 117, 108], [145, 136, 127, 124, 115, 106],
                 [150, 141, 138, 129, 120, 108], [149, 140, 137, 128, 119, 107], [143, 140, 131, 122, 110, 101],
                 [142, 139, 130, 121, 109, 100], [148, 139, 130, 127, 118, 109], [149, 140, 131, 128, 119, 110],
                 [148, 139, 136, 127, 118, 106], [142, 133, 130, 121, 112, 100], [150, 141, 132, 120, 111, 102],
                 [149, 140, 131, 119, 110, 101], [148, 139, 130, 118, 109, 100], [150, 147, 138, 129, 117, 108],
                 [149, 146, 137, 128, 116, 107], [146, 137, 128, 125, 116, 107], [143, 134, 131, 122, 113, 101],
                 [142, 133, 124, 121, 112, 103], [148, 145, 136, 127, 115, 106], [147, 144, 135, 126, 114, 105],
                 [146, 143, 134, 125, 113, 104], [145, 142, 133, 124, 112, 103], [144, 141, 132, 123, 111, 102],
                 [147, 138, 135, 126, 117, 105], [144, 135, 132, 123, 114, 102], [145, 136, 133, 124, 115, 103],
                 [146, 137, 134, 125, 116, 104], [144, 135, 126, 123, 114, 105], [143, 134, 125, 122, 113, 104]]
Costs_large2 = [[56, 67, 78, 86, 97, 108], [55, 66, 77, 85, 96, 107], [60, 71, 79, 90, 101, 120],
                [52, 63, 74, 82, 93, 104], [54, 65, 76, 84, 95, 106], [51, 62, 70, 81, 92, 111],
                [52, 63, 71, 82, 93, 112], [60, 68, 79, 90, 109, 120], [50, 61, 69, 80, 91, 110],
                [51, 62, 73, 81, 92, 103], [50, 61, 72, 80, 91, 102], [53, 64, 72, 83, 94, 113],
                [59, 70, 78, 89, 100, 119], [50, 58, 69, 80, 99, 110], [51, 59, 70, 81, 100, 111],
                [52, 60, 71, 82, 101, 112], [53, 61, 72, 83, 102, 113], [54, 62, 73, 84, 103, 114],
                [58, 69, 77, 88, 99, 118], [57, 68, 79, 87, 98, 109], [55, 63, 74, 85, 104, 115],
                [56, 64, 75, 86, 105, 116], [57, 65, 76, 87, 106, 117], [58, 66, 77, 88, 107, 118],
                [59, 67, 78, 89, 108, 119], [54, 65, 73, 84, 95, 114], [57, 68, 76, 87, 98, 117],
                [56, 67, 75, 86, 97, 116], [55, 66, 74, 85, 96, 115], [53, 64, 75, 83, 94, 105]]

setting_large2 = {
    "numberBuyers": 30,
    "numberSellers": 30,
    "Quantity": 6,
    "bound": 300,
    "Values": Values_large2,
    "Costs": Costs_large2
}
###########
# Large 3 #
###########

# Create vector holding all the values and costs
Values_large3 = [[808, 488, 168], [792, 472, 152], [840, 520, 200], [824, 504, 184], [776, 456, 136],
                 [1000, 680, 360], [984, 664, 344], [968, 648, 328], [952, 632, 312], [936, 616, 296],
                 [904, 584, 264], [920, 600, 280], [696, 376, 56], [888, 568, 248], [872, 552, 232],
                 [856, 536, 216], [760, 440, 120], [712, 392, 72], [728, 408, 88], [744, 424, 104]]
Costs_large3 = [[192, 512, 832], [208, 528, 848], [160, 480, 800], [176, 496, 816], [224, 544, 864],
                [0, 320, 640], [16, 336, 656], [32, 352, 672], [48, 368, 688], [64, 384, 704],
                [96, 416, 736], [80, 400, 720], [304, 624, 944], [112, 432, 752], [128, 448, 768],
                [144, 464, 784], [240, 560, 880], [288, 608, 928], [272, 592, 912], [256, 576, 896]]

setting_large3 = {
    "numberBuyers": 20,
    "numberSellers": 20,
    "Quantity": 3,
    "bound": 1000,
    "Values": Values_large3,
    "Costs": Costs_large3
}

###########
# Large 4 #
###########

# Create vector holding all the values and costs
Values_large4 = [[209, 198, 178], [208, 197, 177], [200, 180, 160], [210, 199, 179], [207, 196, 176],
                 [210, 190, 170], [209, 189, 169], [208, 188, 168], [207, 187, 167], [206, 186, 166],
                 [204, 184, 164], [205, 185, 165], [202, 191, 171], [203, 183, 163], [202, 182, 162],
                 [201, 181, 161], [206, 195, 175], [203, 192, 172], [204, 193, 173], [205, 194, 174]]
Costs_large4 = [[102, 122, 142], [103, 123, 143], [100, 120, 140], [101, 121, 141], [104, 124, 144],
                [90, 110, 130], [91, 111, 131], [92, 112, 132], [93, 113, 133], [94, 114, 134],
                [96, 116, 136], [95, 115, 135], [109, 129, 149], [97, 117, 137], [98, 118, 138],
                [99, 119, 139], [105, 125, 145], [108, 128, 148], [107, 127, 147], [106, 126, 146]]

setting_large4 = {
    "numberBuyers": 20,
    "numberSellers": 20,
    "Quantity": 3,
    "bound": 300,
    "Values": Values_large4,
    "Costs": Costs_large4
}


###########
# Large 5 #
###########

# Create vector holding all the values and costs
Values_large5 = [[140, 139, 138], [139, 138, 137], [142, 141, 140], [141, 140, 139], [138, 137, 136],
                 [123, 122, 121], [125, 124, 123], [124, 123, 122], [127, 126, 125], [126, 125, 124],
                 [108, 107, 106], [111, 110, 109], [112, 111, 110], [109, 108, 107], [110, 109, 108],
                 [150, 149, 100], [149, 148, 147], [133, 132, 131], [136, 135, 134], [137, 136, 135],
                 [134, 133, 132], [135, 134, 133], [122, 121, 120], [121, 120, 119], [120, 119, 118],
                 [119, 118, 117], [118, 117, 116], [103, 102, 101], [107, 106, 105], [106, 105, 104],
                 [105, 104, 103], [104, 103, 102], [147, 146, 145], [146, 145, 144], [145, 144, 143],
                 [144, 143, 142], [143, 142, 141], [128, 127, 126], [129, 128, 127], [130, 129, 128],
                 [131, 130, 129], [132, 131, 130], [150, 101, 100], [150, 149, 148], [148, 147, 146],
                 [114, 113, 112], [115, 114, 113], [116, 115, 114], [117, 116, 115], [113, 112, 111]]
Costs_large5 = [[62, 91, 112], [63, 92, 113], [60, 89, 110], [61, 90, 111], [64, 93, 114],
                [50, 79, 100], [52, 81, 102], [54, 83, 104], [58, 79, 108], [56, 77, 106],
                [57, 78, 107], [54, 75, 104], [55, 76, 105], [52, 73, 94], [70, 91, 120],
                [69, 90, 119], [51, 72, 93], [50, 71, 92], [69, 98, 119], [66, 95, 116],
                [65, 94, 115], [68, 97, 118], [67, 96, 117], [59, 80, 109], [60, 81, 110],
                [61, 82, 111], [62, 83, 112], [63, 84, 113], [51, 80, 101], [53, 82, 103],
                [57, 78, 99], [53, 74, 95], [54, 75, 96], [55, 76, 97], [56, 77, 98],
                [55, 84, 105], [56, 85, 106], [57, 86, 107], [58, 87, 108], [59, 88, 109],
                [53, 74, 103], [52, 73, 102], [51, 72, 101], [50, 71, 100], [70, 99, 120],
                [67, 88, 117], [66, 87, 116], [65, 86, 115], [64, 85, 114], [68, 89, 118]]

setting_large5 = {
    "numberBuyers": 50,
    "numberSellers": 50,
    "Quantity": 3,
    "bound": 300,
    "Values": Values_large5,
    "Costs": Costs_large5
}

# %% [markdown]
# # Simulations

# %%
large_settings = [setting_large1, setting_large2, setting_large3, setting_large4, setting_large5]
save = True

for t in range(5):
    print("==========")
    print("large", t+1)
    sim = simulation(large_settings[t], 1234, 0, 10000)
    print(sim["summary"])
    if save:
        name = "simulation_output_" + "large_" + str(t+1) + ".dta"
        name_detail = "simulation_output_" + "large_" + str(t+1) + "_detail.dta"
        
        dict1 = {
            "auto_corr": sim["output"]["auto_corr"],
            "trx_order_seller": sim["output"]["trx_order_seller"],
            "trx_order_buyer": sim["output"]["trx_order_buyer"],
            "q": sim["output"]["q"]
        }
        df = pd.DataFrame(dict1)
        df.to_stata("simulation_output/" + name)
        
        dict2 = {
            "buyervalue": sim["output_detail"]["buyervalue"],
            "sellercost": sim["output_detail"]["sellercost"],
            "price": sim["output_detail"]["price"],
            "simulation": sim["output_detail"]["simulation"]
        }
        df = pd.DataFrame(dict2)
        df.to_stata("simulation_output/" + name_detail)
# Out:
# ...
# large 1
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/yangzhong/Desktop/ZI simualtion Yang/ZI_large_comp.ipynb Cell 5 line <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/yangzhong/Desktop/ZI%20simualtion%20Yang/ZI_large_comp.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> print("==========")
#       <a href='vscode-notebook-cell:/Users/yangzhong/Desktop/ZI%20simualtion%20Yang/ZI_large_comp.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a> print("large", t+1)
# ----> <a href='vscode-notebook-cell:/Users/yangzhong/Desktop/ZI%20simualtion%20Yang/ZI_large_comp.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a> sim = simulation(large_settings[t], 1234, 0, 10000)
#       <a href='vscode-notebook-cell:/Users/yangzhong/Desktop/ZI%20simualtion%20Yang/ZI_large_comp.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a> print(sim["summary"])
# ...
